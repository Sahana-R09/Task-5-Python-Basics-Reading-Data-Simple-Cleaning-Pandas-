# %%
import pandas as pd
import numpy as np
# Read the dataset
df = pd.read_csv("students_performance_6000.csv")
df.head()
df.info()
# Identify missing values in each column
df.isnull().sum()
# Step 4: Handle missing values
df["math_score"] = df["math_score"].fillna(df["math_score"].median())
df["reading_score"] = df["reading_score"].fillna(df["reading_score"].median())
df["writing_score"] = df["writing_score"].fillna(df["writing_score"].median())
df["parental_level_of_education"] = df["parental_level_of_education"].fillna(
    df["parental_level_of_education"].mode()[0]
)
# Remove duplicate rows
before_rows = df.shape[0]
df = df.drop_duplicates()
after_rows = df.shape[0]

print("Rows before removing duplicates:", before_rows)
print("Rows after removing duplicates:", after_rows)
# Convert data types
df["student_id"] = df["student_id"].astype(str)
# Create new columns
df["average_score"] = df[["math_score", "reading_score", "writing_score"]].mean(axis=1)
def performance_level(score):
    if score < 50:
        return "Low"
    elif score < 75:
        return "Medium"
    else:
        return "High"

df["performance_level"] = df["average_score"].apply(performance_level)
# Final dataset inspection

df.info()
df.head()
#saving cleaned dataset
df.to_csv("cleaned_data.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   student_id                   6000 non-null   int64
#  1   gender                       6000 non-null   object
#  2   race_ethnicity               6000 non-null   object
#  3   parental_level_of_education  5820 non-null   object
#  4   lunch                        6000 non-null   object
#  5   test_preparation_course      3058 non-null   object
#  6   math_score                   5700 non-null   float64
#  7   reading_score                5700 non-null   float64
#  8   writing_score                5700 non-null   float64
#  9   attendance_percentage        6000 non-null   float64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 468.9+ KB
# Rows before removing duplicates: 6000
# Rows after removing duplicates: 6000
# ...
